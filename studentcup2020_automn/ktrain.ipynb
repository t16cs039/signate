# %%
# !pip install ktrain

# %%
import pandas as pd

df_train = pd.read_csv('/content/drive/MyDrive/SIGNATE/DATASET/train.csv')
df_test = pd.read_csv('/content/drive/MyDrive/SIGNATE/DATASET/test.csv')

# %%
from sklearn.model_selection import train_test_split

df_train, df_val = train_test_split(df_train, test_size=0.2, random_state=0)

import ktrain
from ktrain import text

(X_train, y_train), (X_test, y_test), preprocess = text.texts_from_df(train_df=df_train,
                                                                      text_column='html_content',
                                                                      label_columns='state',
                                                                      val_df=df_val,
                                                                      maxlen=300,
                                                                      preprocess_mode='bert')
# Out:
# preprocessing train...
# language: en
# done.
# Is Multi-Label? False
# preprocessing test...
# language: en
# done.

# %%
X_train[0].shape
# Out:
# (8436, 300)

# %%
model = text.text_classifier(name='bert',
                             train_data=(X_train, y_train),
                             preproc=preprocess)
# Out:
# Is Multi-Label? False
# maxlen is 300
# done.

# %%
learner = ktrain.get_learner(model=model,
                             train_data=(X_train, y_train),
                             val_data=(X_test, y_test),
                             batch_size=32,)
# Out:
# /usr/local/lib/python3.6/dist-packages/ktrain/__init__.py:90: UserWarning: For a GPU with 12GB of RAM, the following maxima apply:
#         sequence len=64, max_batch_size=64
#         sequence len=128, max_batch_size=32
#         sequence len=256, max_batch_size=16
#         sequence len=320, max_batch_size=14
#         sequence len=384, max_batch_size=12
#         sequence len=512, max_batch_size=6
#
#         You've exceeded these limits.
#         If using a GPU with <=12GB of memory, you may run out of memory during training.
#         If necessary, adjust sequence length or batch size based on above.
#   if wrn: I.warnings.warn(msg)

# %%
# learner.lr_find()
# learner.lr_plot()

learner.fit_onecycle(lr=2e-5, 
                     epochs=1,)
# Out:
# begin training using onecycle policy with max lr of 2e-05...
# ---------------------------------------------------------------------------
# ResourceExhaustedError                    Traceback (most recent call last)
# <ipython-input-7-e78c2ce9d066> in <module>()
#       3
#       4 learner.fit_onecycle(lr=2e-5,
# ----> 5                      epochs=1,)
#
# /usr/local/lib/python3.6/dist-packages/ktrain/core.py in fit_onecycle(self, lr, epochs, checkpoint_folder, cycle_momentum, max_momentum, min_momentum, class_weight, callbacks, steps_per_epoch, verbose)
#     858                         checkpoint_folder=checkpoint_folder,
#     859                         verbose=verbose, class_weight=class_weight, callbacks=kcallbacks,
# --> 860                         steps_per_epoch=steps_per_epoch)
#     861         hist.history['lr'] = clr.history['lr']
#     862         hist.history['iterations'] = clr.history['iterations']
#
# ...

# %%
predictor = ktrain.get_predictor(learner.model, preprocess)

# %%
df_sub = pd.DataFrame(predictor.predict(df_test['html_content'].values))
df_sub = pd.concat([df['id'], df_sub], axis=0)
df_sub.to_csv('submission.csv', index=False, header=False)

print('df_sub shape: {0}'.format(df_sub.shape))
df_sub.head()

# %%
{}
